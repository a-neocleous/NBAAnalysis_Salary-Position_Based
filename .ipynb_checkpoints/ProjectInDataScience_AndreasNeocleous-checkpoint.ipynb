# %% [markdown]
# # <b> <font color='red'>  Project in Data Science </font> </b>

# %% [markdown]
# ## Analysing NBA historical data to discover patterns that should be adopted by franchises to succeed
#
# #### <b>Andreas Neocleous
# a.neocleous12@hotmail.com
# </b>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

# %% [markdown]
# ### Scraping as a test from hoopshype site

# %%
url="https://hoopshype.com/salaries/players/"

r = requests.get(url,timeout=2.5)
r_html = r.text

soup = BeautifulSoup(r_html, 'html.parser')

salary_table = soup.find('table')

# %%
length=len(salary_table.find_all("td"))

player_names=[salary_table.find_all("td")[i].text.strip() for i in range(9,length,8)]

column1=[salary_table.find_all("td")[i].text.strip() for i in range(10,length,8)]
column2=[salary_table.find_all("td")[i].text.strip() for i in range(11,length,8)]
column3=[salary_table.find_all("td")[i].text.strip() for i in range(12,length,8)]
column4=[salary_table.find_all("td")[i].text.strip() for i in range(13,length,8)]
column5=[salary_table.find_all("td")[i].text.strip() for i in range(14,length,8)]
column6=[salary_table.find_all("td")[i].text.strip() for i in range(15,length,8)]

# %%
df_dict={'player_names':player_names,
        'salary ($)':column1}
        
salary_df=pd.DataFrame(df_dict)
salary_df[:5]
# Out:
#         player_names   salary ($)
# 0      Stephen Curry  $45,780,966
# 1          John Wall  $44,310,840
# 2       James Harden  $44,310,840
# 3  Russell Westbrook  $44,211,146
# 4       Kevin Durant  $42,018,900

# %% [markdown]
# ### Transform salaries to numeric values

# %%
salary_df.replace({'\$':''}, regex = True,inplace=True)
salary_df.replace(',','', regex=True, inplace=True)

for item in salary_df.columns[1:]:
    
    salary_df[item]=pd.to_numeric(salary_df[item])
    
salary_df[:5]
# Out:
#         player_names  salary ($)
# 0      Stephen Curry    45780966
# 1          John Wall    44310840
# 2       James Harden    44310840
# 3  Russell Westbrook    44211146
# 4       Kevin Durant    42018900

# %% [markdown]
# ### Creating arrays of years and team names in order to feed them as f string to for loops which is going to create for us all the DataFrames we need

# %%
years=[]
for i in range(2020,2000,-1):
    years.append(f"{i}-{i+1}")

team_names = ["portland_trail_blazers","oklahoma_city_thunder","los_angeles_clippers","cleveland_cavaliers","philadelphia_76ers",
              "miami_heat","golden_state_warriors","denver_nuggets","houston_rockets","orlando_magic",
              "los_angeles_lakers","milwaukee_bucks","toronto_raptors","washington_wizards","dallas_mavericks",
              "san_antonio_spurs","utah_jazz","brooklyn_nets","new_orleans_pelicans","boston_celtics",
              "minnesota_timberwolves","sacramento_kings","indiana_pacers","chicago_bulls","atlanta_hawks",
              "detroit_pistons","new_york_knicks","phoenix_suns","memphis_grizzlies","charlotte_hornets"]            
              
print(years)
print(team_names)
print(len(years))
print(len(team_names))
# Out:
# ['2020-2021', '2019-2020', '2018-2019', '2017-2018', '2016-2017', '2015-2016', '2014-2015', '2013-2014', '2012-2013', '2011-2012', '2010-2011', '2009-2010', '2008-2009', '2007-2008', '2006-2007', '2005-2006', '2004-2005', '2003-2004', '2002-2003', '2001-2002']
# ['portland_trail_blazers', 'oklahoma_city_thunder', 'los_angeles_clippers', 'cleveland_cavaliers', 'philadelphia_76ers', 'miami_heat', 'golden_state_warriors', 'denver_nuggets', 'houston_rockets', 'orlando_magic', 'los_angeles_lakers', 'milwaukee_bucks', 'toronto_raptors', 'washington_wizards', 'dallas_mavericks', 'san_antonio_spurs', 'utah_jazz', 'brooklyn_nets', 'new_orleans_pelicans', 'boston_celtics', 'minnesota_timberwolves', 'sacramento_kings', 'indiana_pacers', 'chicago_bulls', 'atlanta_hawks', 'detroit_pistons', 'new_york_knicks', 'phoenix_suns', 'memphis_grizzlies', 'charlotte_hornets']
# 20
# 30

# %% [markdown]
# ### Create a testing DataFrame by using f-strings

# %%
url=f"https://hoopshype.com/salaries/{team_names[0]}/{years[0]}/"
print(url)

r = requests.get(url,timeout=2.5)
r_html = r.text

soup = BeautifulSoup(r_html, 'html.parser')

salary_table = soup.find('table')



length=len(salary_table.find_all("td"))
player_names=[salary_table.find_all("td")[i].text.strip() for i in range(3,length,3)]
column1=[salary_table.find_all("td")[i].text.strip() for i in range(4,length,3)]

df_dict={'player_names':player_names,
        'salary ($)':column1}
        
salary_portland20_21=pd.DataFrame(df_dict)
# Out:
# https://hoopshype.com/salaries/portland_trail_blazers/2020-2021/

# %%
salary_portland20_21.replace({'\$':''}, regex = True,inplace=True)
salary_portland20_21.replace(',','', regex=True, inplace=True)

for item in salary_portland20_21.columns[1:]:
    
    salary_portland20_21[item]=pd.to_numeric(salary_df[item])
    
salary_portland20_21[:5]
# Out:
#        player_names  salary ($)
# 0    Damian Lillard    45780966
# 1       CJ McCollum    44310840
# 2      Jusuf Nurkic    44310840
# 3  Robert Covington    44211146
# 4     Norman Powell    42018900

# %% [markdown]
# ### We are going to create a dictionary with keys being name of teams plus year using f-strings and their values will be their payroll as a DataFrame

# %%
payrolls_noPositions=dict()
counter=0
for i in range(0,len(team_names)):
    for j in range(0,len(years)):
        
        url = f"https://hoopshype.com/salaries/{team_names[i]}/{years[j]}/"
        
        salary_table = []
        try:
            r = requests.get(url,timeout=3)
            r_html = r.text
            soup = BeautifulSoup(r_html, 'html.parser')
            salary_table = soup.find('table')
        except:
            print("Something wrong")

        length=len(salary_table.find_all("td"))
        player_names=[salary_table.find_all("td")[i].text.strip() for i in range(3,length,3)]
        column1=[salary_table.find_all("td")[i].text.strip() for i in range(4,length,3)]
        
        
        salary_table = []
        try:
            r = requests.get(url,timeout=3)
            r_html = r.text
            soup = BeautifulSoup(r_html, 'html.parser')
            salary_table = soup.find('table')
        except:
            print("Something wrong")

        df_dict={'player_names':player_names,
                'salary ($)':column1}
        
        
        
        tempDataFrame=pd.DataFrame(df_dict)
        
        tempDataFrame.replace({'\$':''}, regex = True,inplace=True)
        tempDataFrame.replace(',','', regex=True, inplace=True)
        for item in tempDataFrame.columns[1:2]:
            tempDataFrame[item]=pd.to_numeric(tempDataFrame[item])
            
        print(tempDataFrame)
        counter=counter+1
        if counter%25==0:
            print(counter)
        payrolls_noPositions[f"{team_names[i]}{years[j]}"] = tempDataFrame

print(counter,len(payrolls_noPositions))
# Out:
#                player_names  salary ($)
# 0            Damian Lillard    31626953
# 1               CJ McCollum    29354152
# 2              Jusuf Nurkic    12888889
# 3          Robert Covington    12138345
# 4             Norman Powell    10865952
# 5             Derrick Jones     9258000
# 6              Zach Collins     5406255
# 7               Enes Kanter     5005350
# 8          Andrew Nicholson     2844429
# 9           Carmelo Anthony     2564753
# 10          Anfernee Simons     2252040
# 11            Nassir Little     2210640
# 12         Anderson Varejao     1913345
# 13              Harry Giles     1620564
# 14                CJ Elleby      898310
# 15  Rondae Hollis-Jefferson      502957
# 16           Keljin Blevins      449115
# 17                  TJ Leaf      104598
# 18                   Totals   131904647
#         player_names  salary ($)
# 0     Damian Lillard    29802321
# 1        CJ McCollum    27556959
# 2   Hassan Whiteside    27093018
# 3       Trevor Ariza    12200000
# 4       Jusuf Nurkic    12000000
# 5        Rodney Hood     5718000
# 6       Zach Collins     4240200
# 7    Carmelo Anthony     2159029
# 8    Anfernee Simons     2149560
# 9      Nassir Little     2105520
# 10    Caleb Swanigan     2033160
# 11     Mario Hezonja     1737145
# 12    Wenyen Gabriel     1445697
# 13     Gary Trent Jr     1416852
# 14      Jaylen Adams      163356
# 15       Moses Brown       79568
# 16      Jaylen Hoard       79568
# 17            Totals   131979953
#         player_names  salary ($)
# 0     Damian Lillard    27977689
# 1        CJ McCollum    25759766
# 2        Evan Turner    17868853
# 3       Jusuf Nurkic    11111111
# 4       Moe Harkless    10837079
# 5     Meyers Leonard    10595506
# 6    Al-Farouq Aminu     6957105
# 7       Zach Collins     3628920
# 8        Rodney Hood     3472887
# 9   Andrew Nicholson     2844429
# 10        Seth Curry     2795000
# 11   Anfernee Simons     1837800
# 12       Jake Layman     1544951
# 13   Skal Labissiere     1544951
# 14     Gary Trent Jr      838464
# 15       Enes Kanter      642089
# 16            Totals   130256600
#             player_names  salary ($)
# 0         Damian Lillard    26153057
# 1            CJ McCollum    23962573
# 2            Evan Turner    17131148
# 3           Moe Harkless    10662922
# 4         Meyers Leonard     9904495
# 5        Al-Farouq Aminu     7319035
# 6               Ed Davis     6352531
# 7           Zach Collins     3057240
# 8           Jusuf Nurkic     2947304
# 9       Andrew Nicholson     2844429
# 10        Shabazz Napier     2361359
# 11       Pat Connaughton     1471382
# 12        Caleb Swanigan     1465920
# 13           Jake Layman     1312611
# 14          Festus Ezeli     1000000
# 15          Wade Baldwin      379892
# 16  Georgios Papagiannis      185397
# 17          Brandon Rush      119601
# 18             CJ Wilcox       77250
# 19                Totals   118708146
#         player_names  salary ($)
# 0     Damian Lillard    24328425
# 1       Allen Crabbe    18500000
# 2        Evan Turner    16393443
# 3   Anderson Varejao     9300000
# 4     Meyers Leonard     9213484
# 5       Moe Harkless     8988764
# 6    Al-Farouq Aminu     7680965
# 7       Festus Ezeli     7400000
# 8           Ed Davis     6666667
# 9        CJ McCollum     3219579
# 10       Noah Vonleh     2751360
# 11      Jusuf Nurkic     1921320
# 12    Shabazz Napier     1350120
# 13   Pat Connaughton      874636
# 14       Jake Layman      600000
# 15    Tim Quarterman      543471
# 16            Totals   119732234
#         player_names  salary ($)
# 0   Anderson Varejao     9700000
# 1    Al-Farouq Aminu     8042895
# 2           Ed Davis     6980802
# 3   Gerald Henderson     6000000
# 4        Chris Kaman     5000000
# 5     Damian Lillard     4236286
# 6     Meyers Leonard     3075879
# 7       Moe Harkless     2894058
# 8        Mike Miller     2854940
# 9      Brian Roberts     2854940
# 10       Noah Vonleh     2637720
# 11       CJ McCollum     2525160
# 12     Mason Plumlee     1415520
# 13      Allen Crabbe      947276
# 14       Tim Frazier      845059
# 15   Pat Connaughton      625093
# 16   Cliff Alexander      525093
# 17      Luis Montero      525093
# 18            Totals    61685814
#          player_names  salary ($)
# 0   LaMarcus Aldridge    15200000
# 1         Brandon Roy    14399332
# 2       Nicolas Batum    11390500
# 3       Arron Afflalo     7562500
# 4     Wesley Matthews     7245640
# 5         Robin Lopez     5340229
# 6         Chris Kaman     4800000
# 7      Damian Lillard     3340920
# 8       Dorell Wright     3145000
# 9       Joel Freeland     3100000
# 10        CJ McCollum     2421000
# 11     Meyers Leonard     2317920
# 12        Steve Blake     2100000
# 13         Alonzo Gee     1063384
# 14       Allen Crabbe      862000
# 15        Tim Frazier       47749
# 16             Totals    69936842
#          player_names  salary ($)
# 0         Brandon Roy    17779458
# 1   LaMarcus Aldridge    14100000
# 2       Nicolas Batum    10920250
# 3     Wesley Matthews     6875480
# 4         Robin Lopez     5119761
# 5     Thomas Robinson     3526440
# 6      Damian Lillard     3202920
# 7       Joel Freeland     3000000
# 8       Dorell Wright     3000000
# 9    Maurice Williams     2652000
# 10        CJ McCollum     2316720
# 11     Meyers Leonard     2222160
# 12        Earl Watson     1399507
# 13      Victor Claver     1311240
# 14       Allen Crabbe      825000
# 15        Will Barton      788872
# 16             Totals    61260350
#            player_names  salary ($)
# 0           Brandon Roy    16359805
# 1     LaMarcus Aldridge    13000000
# 2         Nicolas Batum    11950000
# 3       Wesley Matthews     6505320
# 4            JJ Hickson     4000000
# 5       Shawne Williams     3158000
# 6        Damian Lillard     3065040
# 7         Joel Freeland     2900000
# 8           Eric Maynor     2338720
# 9        Meyers Leonard     2126520
# 10         Luke Babbitt     1892280
# 11       Jared Jeffries     1475106
# 12      Elliot Williams     1442880
# 13          Nolan Smith     1404960
# 14        Victor Claver     1254720
# 15  Aleksandar Pavlovic     1232713
# 16         Ronnie Price     1146337
# 17          Will Barton      550000
# 18               Totals    59442596
#          player_names  salary ($)
# 0         Brandon Roy    16032144
# 1   LaMarcus Aldridge    12372000
# 2        Marcus Camby    11227250
# 3      Gerald Wallace     9500000
# 4      Raymond Felton     7560000
# 5     Wesley Matthews     6135160
# 6      Jamal Crawford     5000000
# 7       Nicolas Batum     2155365
# 8        Luke Babbitt     1768800
# 9           Greg Oden     1500000
# 10        Kurt Thomas     1352181
# 11    Elliot Williams     1348800
# 12        Nolan Smith     1306920
# 13     Joel Przybilla     1145027
# 14        Craig Smith      992680
# 15      Chris Johnson      762195
# 16      Armon Johnson      762195
# 17             Totals    80920717
#          player_names  salary ($)
# 0         Brandon Roy    13520500
# 1        Marcus Camby    11749832
# 2   LaMarcus Aldridge    11244000
# 3      Gerald Wallace    10500000
# 4        Andre Miller     7269264
# 5           Greg Oden     6760524
# 6     Wesley Matthews     5765000
# 7        Luke Babbitt     1645440
# 8     Elliot Williams     1254720
# 9      Rudy Fernandez     1246680
# 10      Nicolas Batum     1196760
# 11    Fabricio Oberto      992680
# 12      Patrick Mills      937195
# 13      Armon Johnson      473604
# 14      Chris Johnson       27859
# 15             Totals    74584058
#          player_names  salary ($)
# 0        Darius Miles     9000000
# 1        Marcus Camby     7650000
# 2      Joel Przybilla     6857725
# 3        Andre Miller     6730800
# 4   LaMarcus Aldridge     5844827
# 5           Greg Oden     5361240
# 6     Martell Webster     4344000
# 7         Brandon Roy     3910816
# 8      Jerryd Bayless     2143080
# 9        Juwan Howard     1306455
# 10     Rudy Fernandez     1165320
# 11      Nicolas Batum     1118760
# 12   Dante Cunningham      457588
# 13         Jeff Ayres      457588
# 14      Patrick Mills      457588
# 15   Shavlik Randolph       88488
# 16   Anthony Tolliver       51983
# 17             Totals    56946258
#          player_names  salary ($)
# 0       Steve Francis    17180000
# 1       Raef LaFrentz    12722500
# 2        Darius Miles     9000000
# 3      Joel Przybilla     6310150
# 4           Greg Oden     5011680
# 5   LaMarcus Aldridge     4631400
# 6         Steve Blake     4250000
# 7       Travis Outlaw     4000000
# 8     Martell Webster     3771133
# 9       Channing Frye     3163769
# 10        Brandon Roy     3084240
# 11     Jerryd Bayless     1993560
# 12     Michael Ruffin     1141838
# 13     Rudy Fernandez     1084080
# 14   Sergio Rodriguez     1048800
# 15      Nicolas Batum     1040640
# 16   Shavlik Randolph      826269
# 17             Totals    80260059
#          player_names  salary ($)
# 0       Steve Francis    15070000
# 1       Raef LaFrentz    12440787
# 2        Darius Miles     8250000
# 3      Joel Przybilla     5762575
# 4           Greg Oden     4662000
# 5   LaMarcus Aldridge     4329360
# 6         Steve Blake     4250000
# 7       Travis Outlaw     4000000
# 8     Martell Webster     2974080
# 9         James Jones     2900000
# 10        Brandon Roy     2883120
# 11      Channing Frye     2487240
# 12       Jarrett Jack     1217400
# 13   Sergio Rodriguez      817000
# 14          Von Wafer      770610
# 15     Josh McRoberts      427163
# 16             Totals    73241335
#          player_names  salary ($)
# 0       Zach Randolph    12000000
# 1       Raef LaFrentz    11532037
# 2      Derek Anderson     9742500
# 3     Jamaal Magloire     8433334
# 4        Darius Miles     7750000
# 5      Joel Przybilla     5215000
# 6   LaMarcus Aldridge     4027320
# 7          Fred Jones     3100000
# 8     Martell Webster     2780160
# 9          Dan Dickau     2753218
# 10        Brandon Roy     2681880
# 11      Travis Outlaw     1836426
# 12       Jarrett Jack     1137960
# 13   Sergio Rodriguez      912000
# 14          Ime Udoka      744551
# 15     Stephen Graham      259204
# 16  Jeremy Richardson      120796
# 17             Totals    75026386
#          player_names  salary ($)
# 0        Theo Ratliff    11666666
# 1       Zach Randolph    10666667
# 2      Derek Anderson     9093000
# 3        Darius Miles     7250000
# 4     Ruben Patterson     6353200
# 5     Martell Webster     2586120
# 6          Juan Dixon     2500000
# 7   Sebastian Telfair     1676280
# 8      Joel Przybilla     1560000
# 9      Viktor Khryapa     1095960
# 10      Travis Outlaw     1082160
# 11       Jarrett Jack     1058640
# 12       Sergey Monya     1016400
# 13        Steve Blake     1000000
# 14      Charles Smith      771123
# 15       Ha Seung-Jin      641748
# 16             Totals    60017964
#            player_names  salary ($)
# 0   Shareef Abdur-Rahim    14625000
# 1      Damon Stoudamire    12500000
# 2         Nick Van Exel    11933252
# 3          Theo Ratliff    10937500
# 4        Derek Anderson     8443500
# 5          Darius Miles     6750000
# 6       Ruben Patterson     5899400
# 7       Arvydas Sabonis     3000000
# 8     Sebastian Telfair     1559280
# 9         Zach Randolph     1504272
# 10       Joel Przybilla     1500000
# 11         Qyntel Woods     1127280
# 12    Vladimir Stepania     1100000
# 13       Viktor Khryapa     1019400
# 14        Travis Outlaw     1011600
# 15         Richie Frahm      695046
# 16        Geno Carlisle       65779
# 17               Totals    83671309
#              player_names  salary ($)
# 0         Rasheed Wallace    17000000
# 1              Shawn Kemp    14941935
# 2        Damon Stoudamire    12375000
# 3              Dale Davis     9061875
# 4          Derek Anderson     7794000
# 5           Wesley Person     7700000
# 6         Ruben Patterson     5445600
# 7            Jeff McInnis     3300000
# 8           Zach Randolph     1172160
# 9            Qyntel Woods     1053720
# 10          Travis Outlaw      941040
# 11      Vladimir Stepania      751179
# 12  Ruben Boumtje-Boumtje      663679
# 13           Matt Carroll      349032
# 14         Kaniel Dickens      264011
# 15           Tracy Murray      143537
# 16                 Totals    82956768
#              player_names  salary ($)
# 0          Scottie Pippen    19727524
# 1         Rasheed Wallace    16200000
# 2              Shawn Kemp    12621028
# 3        Damon Stoudamire    12375000
# 4              Dale Davis     8055000
# 5          Derek Anderson     7144500
# 6         Arvydas Sabonis     6850000
# 7             Bonzi Wells     6300000
# 8         Ruben Patterson     4991800
# 9         Antonio Daniels     3375000
# 10           Jeff McInnis     3000000
# 11          Zach Randolph     1095720
# 12           Chris Dudley     1030000
# 13           Qyntel Woods      980280
# 14         Amal McCaskill      699935
# 15          Charles Smith      637435
# 16  Ruben Boumtje-Boumtje      512435
# 17                 Totals   105595657
#              player_names  salary ($)
# 0          Scottie Pippen    18083564
# 1         Rasheed Wallace    14400000
# 2              Shawn Kemp    12660000
# 3        Damon Stoudamire    12375000
# 4              Dale Davis     7010000
# 5          Derek Anderson     6495000
# 6         Ruben Patterson     4538000
# 7              Steve Kerr     2406250
# 8             Bonzi Wells     2028239
# 9           Zach Randolph     1019280
# 10           Chris Dudley     1000000
# 11        Mitchell Butler      715850
# 12          Erick Barkley      638000
# 13           Rick Brunson      590850
# 14  Ruben Boumtje-Boumtje      332817
# 15                 Totals    84292850
#                player_names  salary ($)
# 0                Al Horford    27500000
# 1            Meyers Leonard     9400000
# 2             Darius Miller     7000000
# 3            Justin Jackson     5029650
# 4                   TJ Leaf     4326825
# 5   Shai Gilgeous-Alexander     4141320
# 6              Gabriel Deck     3870370
# 7              Tony Bradley     3542060
# 8             Austin Rivers     3500000
# 9        Aleksej Pokusevski     2964840
# 10            Darius Bazley     2399160
# 11                Ty Jerome     2303040
# 12             Mike Muscala     2283034
# 13         Kenrich Williams     2000000
# 14             Theo Maledon     2000000
# 15    Sviatoslav Mykhailiuk     1663861
# 16                Josh Gray     1620564
# 17            Luguentz Dort     1517981
# 18              Isaiah Roby     1517981
# 19        Admiral Schofield     1517981
# 20           Zylan Cheatham     1445697
# 21              Moses Brown     1250000
# 22             Kyle Singler      999200
# 23        Patrick Patterson      737067
# 24                Josh Hall      449115
# 25            Frank Jackson      250000
# 26            Charlie Brown      217844
# 27          Justin Robinson      198040
# 28             Jaylen Hoard      129209
# 29                   Totals    95774839
#                player_names  salary ($)
# 0                Chris Paul    38506482
# 1              Steven Adams    25842697
# 2          Danilo Gallinari    22615559
# 3          Dennis Schroeder    15500000
# 4            Andre Roberson    10740740
# 5   Shai Gilgeous-Alexander     3952920
# 6         Terrance Ferguson     2475840
# 7             Darius Bazley     2284800
# 8              Mike Muscala     2028594
# 9              Nerlens Noel     1882867
# 10              Abdel Nader     1618520
# 11              Isaiah Roby     1500000
# 12           Hamidou Diallo     1416852
# 13            Deonte Burton     1416852
# 14            Luguentz Dort      155647
# 15             Kevin Hervey       79568
# 16                   Totals   132017938
#          player_names  salary ($)
# 0   Russell Westbrook    35665000
# 1         Paul George    30560700
# 2        Steven Adams    24157304
# 3    Dennis Schroeder    15500000
# 4      Andre Roberson    10000000
# 5        Jerami Grant     8333333
# 6   Patrick Patterson     5451600
# 7        Alex Abrines     3667645
# 8      Raymond Felton     2393887
# 9   Terrance Ferguson     2118840
# 10       Nerlens Noel     1757429
# 11       Kyle Singler     1665333
# 12        Abdel Nader     1378242
# 13     Hamidou Diallo      838464
# 14    Markieff Morris      573294
# 15      Deonte Burton      500000
# 16        Tyler Davis       77250
# 17     Donte Grantham       77250
# 18        Jawun Evans       77250
# 19      Scotty Hopson       76236
# 20    Richard Solomon       47370
# 21             Totals   144916427
#          player_names  salary ($)
# 0   Russell Westbrook    28299399
# 1     Carmelo Anthony    26243760
# 2        Steven Adams    22471911
# 3         Paul George    19300000
# 4      Andre Roberson     9259260
# 5        Alex Abrines     5725000
# 6   Patrick Patterson     5192000
# 7        Kyle Singler     4666500
# 8        Ronnie Price     2442455
# 9      Raymond Felton     2328652
# 10      Nick Collison     2328652
# 11  Terrance Ferguson     1785000
# 12       Jerami Grant     1524305
# 13       Josh Huestis     1471382
# 14     Dakari Johnson      815615
# 15       Corey Brewer      526249
# 16    Daniel Hamilton       77250
# 17          PJ Dozier       77250
# 18             Totals   134534640
#          player_names  salary ($)
# 0   Russell Westbrook    26540100
# 1         Enes Kanter    17145838
# 2          Taj Gibson     8950000
# 3      Victor Oladipo     6552960
# 4        Alex Abrines     5994764
# 5        Kyle Singler     4837500
# 6       Nick Collison     3750000
# 7        Steven Adams     3140517
# 8        Ronnie Price     2557545
# 9      Doug McDermott     2483040
# 10   Domantas Sabonis     2440200
# 11     Andre Roberson     2183072
# 12       Mitch McGary     1526040
# 13       Josh Huestis     1191480
# 14       Jerami Grant      980431
# 15     Semaj Christon      543471
# 16        Norris Cole      288131
# 17   Kaleb Tarczewski       75000
# 18        Alex Caruso       50000
# 19             Totals    91230089
# 25
#          player_names  salary ($)
# 0        Kevin Durant    21971850
# 1   Russell Westbrook    16744218
# 2         Enes Kanter    16407500
# 3         Serge Ibaka    12250000
# 4        Dion Waiters     5138430
# 5        Kyle Singler     4500000
# 6       Nick Collison     3750000
# 7      Anthony Morrow     3344000
# 8          Randy Foye     3135000
# 9        Steven Adams     2279040
# 10      Cameron Payne     2021520
# 11       Mitch McGary     1463040
# 12     Andre Roberson     1210800
# 13       Josh Huestis     1140240
# 14      Nazr Mohammed      352749
# 15             Totals    95708387
#          player_names  salary ($)
# 0        Kevin Durant    19997513
# 1   Russell Westbrook    15719062
# 2         Serge Ibaka    12250000
# 3         Enes Kanter     6008106
# 4        Dion Waiters     4062000
# 5         Steve Novak     3445947
# 6      Anthony Morrow     3200000
# 7         DJ Augustin     3000000
# 8       Nick Collison     2242003
# 9         Jeremy Lamb     2202000
# 10       Steven Adams     2184960
# 11       Mitch McGary     1400040
# 12  Sebastian Telfair     1316809
# 13     Andre Roberson     1160880
# 14        Perry Jones     1129200
# 15       Kyle Singler     1090000
# 16             Totals    80408520
#          player_names  salary ($)
# 0        Kevin Durant    18773176
# 1   Russell Westbrook    14693906
# 2         Serge Ibaka    12250000
# 3    Kendrick Perkins     8477437
# 4     Thabo Sefolosha     3900000
# 5       Nick Collison     2585668
# 6         Jeremy Lamb     2111160
# 7        Steven Adams     2090880
# 8        Derek Fisher     1399507
# 9      Reggie Jackson     1329720
# 10    Hasheem Thabeet     1200000
# 11     Andre Roberson     1110840
# 12        Perry Jones     1082520
# 13       Caron Butler      386992
# 14    Reggie Williams      111518
# 15         Royal Ivey       74839
# 16     Mustafa Shakur       46404
# 17      Grant Jerrett       28834
# 18             Totals    71653401
#          player_names  salary ($)
# 0        Kevin Durant    17548838
# 1   Russell Westbrook    13668750
# 2        Kevin Martin    12939675
# 3    Kendrick Perkins     7800531
# 4     Thabo Sefolosha     3600000
# 5       Nick Collison     2929332
# 6         Serge Ibaka     2253061
# 7         Jeremy Lamb     2020200
# 8      Reggie Jackson     1243080
# 9       Ronnie Brewer     1069509
# 10        Perry Jones     1035960
# 11    Hasheem Thabeet      885120
# 12    DeAndre Liggins      762195
# 13       Daniel Orton      762195
# 14       Derek Fisher      405654
# 15             Totals    68924100
#          player_names  salary ($)
# 0        Kevin Durant    15506632
# 1    Kendrick Perkins     7123626
# 2   Russell Westbrook     5082416
# 3        James Harden     4604760
# 4       Nate Robinson     4500000
# 5       Nazr Mohammed     3750000
# 6        Daequan Cook     3341558
# 7     Thabo Sefolosha     3300000
# 8       Nick Collison     3272997
# 9        Cole Aldrich     2286000
# 10        Eric Maynor     1516680
# 11        Serge Ibaka     1288200
# 12         Royal Ivey     1200000
# 13     Reggie Jackson     1156320
# 14      Lazar Hayward     1097520
# 15          Ryan Reid      475000
# 16             Totals    59501709
#          player_names  salary ($)
# 0       Nick Collison    13250000
# 1       Nazr Mohammed     6883800
# 2        Kevin Durant     6053663
# 3    Kendrick Perkins     4640208
# 4        James Harden     4304520
# 5       Nate Robinson     4200000
# 6   Russell Westbrook     4017720
# 7     Thabo Sefolosha     3250000
# 8        Daequan Cook     2169857
# 9        Cole Aldrich     2126520
# 10        Eric Maynor     1417800
# 11        Serge Ibaka     1204200
# 12         BJ Mullens     1204200
# 13         Royal Ivey     1200000
# 14             Totals    55922488
#          player_names  salary ($)
# 0         Etan Thomas     7350000
# 1         Earl Watson     6600000
# 2       Matt Harpring     6500000
# 3       Nick Collison     6250000
# 4        Nenad Krstic     5400000
# 5        Kevin Durant     4796880
# 6        James Harden     4054160
# 7   Russell Westbrook     3755640
# 8          Jeff Green     3516960
# 9     Thabo Sefolosha     2759628
# 10        Eric Maynor     1318920
# 11        Kevin Ollie     1306455
# 12        Serge Ibaka     1120200
# 13         BJ Mullens     1120200
# 14           DJ White     1036440
# 15        Kyle Weaver      870968
# 16   Shaun Livingston      296695
# 17         Ryan Bowen      209592
# 18         Mike Wilks      175908
# 19   Antonio Anderson      139968
# 20             Totals    58578614
#          player_names  salary ($)
# 0          Malik Rose     7647500
# 1       Nick Collison     6350000
# 2         Earl Watson     6200000
# 3    Donyell Marshall     5950894
# 4       Desmond Mason     5300000
# 5           Joe Smith     4795000
# 6        Nenad Krstic     4778548
# 7        Kevin Durant     4484040
# 8        Robert Swift     3579131
# 9   Russell Westbrook     3493680
# 10         Jeff Green     3287640
# 11      Chucky Atkins     3240000
# 12     Damien Wilkins     3100000
# 13          Saer Sene     2252400
# 14    Thabo Sefolosha     1931160
# 15           DJ White      964080
# 16        Kyle Weaver      806452
# 17        Steven Hill      148238
# 18         John Lucas       32842
# 19             Totals    68341605
#         player_names  salary ($)
# 0       Chris Wilcox     6500000
# 1       Luke Ridnour     6500000
# 2   Donyell Marshall     6016965
# 3        Earl Watson     5800000
# 4      Nick Collison     5750000
# 5        Brent Barry     5544370
# 6       Kevin Durant     4171200
# 7         Ira Newble     3441900
# 8         Jeff Green     3058200
# 9    Francisco Elson     3000000
# 10    Damien Wilkins     2900000
# 11      Robert Swift     2601113
# 12         Saer Sene     2105520
# 13    Adrian Griffin     1593000
# 14       Johan Petro     1077120
# 15  Mickael Gelabale      802000
# 16            Totals    60861388
#            player_names  salary ($)
# 0             Ray Allen    14611570
# 1         Rashard Lewis     9350649
# 2         Danny Fortson     6596990
# 3          Chris Wilcox     6250000
# 4           Earl Watson     5400000
# 5        Damien Wilkins     2700000
# 6         Nick Collison     2501070
# 7          Luke Ridnour     2425878
# 8             Saer Sene     1958640
# 9          Robert Swift     1887600
# 10          Johan Petro     1006800
# 11     Mickael Gelabale      802000
# 12           Mike Wilks      798112
# 13        Desmon Farmer      275404
# 14          Andre Brown      241591
# 15  Andreas Glyniadakis      161061
# 16          Kareem Rush       19466
# 17               Totals    56986831
#            player_names  salary ($)
# 0             Ray Allen    13223140
# 1         Rashard Lewis     8571429
# 2         Danny Fortson     6207670
# 3      Vitaly Potapenko     3320000
# 4   Vladimir Radmanovic     3166155
# 5        Damien Wilkins     2500000
# 6         Nick Collison     1815000
# 7          Robert Swift     1764480
# 8           Ibo Kutluay     1760000
# 9          Luke Ridnour     1638000
# 10         Reggie Evans     1100000
# 11         Rick Brunson     1029873
# 12          Mikki Moore     1020000
# 13          Johan Petro      936600
# 14        Ronald Murray      895248
# 15       Mateen Cleaves      305784
# 16               Totals    49253379
#            player_names  salary ($)
# 0             Ray Allen    14625000
# 1         Rashard Lewis     7792208
# 2      Vitaly Potapenko     6191250
# 3         Danny Fortson     5818136
# 4          Jerome James     5455200
# 5   Vladimir Radmanovic     2300984
# 6       Antonio Daniels     2200000
# 7         Nick Collison     1969680
# 8          Robert Swift     1641360
# 9           Ibo Kutluay     1600000
# 10         Luke Ridnour     1531200
# 11         Reggie Evans      880000
# 12       Mateen Cleaves      735960
# 13        Ronald Murray      695046
# 14       Damien Wilkins      385277
# 15               Totals    53821301
#            player_names  salary ($)
# 0             Ray Allen    13500000
# 1         Rashard Lewis     7012987
# 2      Vitaly Potapenko     5715000
# 3          Calvin Booth     5446800
# 4           Brent Barry     5400000
# 5          Jerome James     5000600
# 6       Antonio Daniels     2200000
# 7   Vladimir Radmanovic     1669800
# 8         Nick Collison     1578240
# 9          Luke Ridnour     1424400
# 10         Joseph Forte     1080360
# 11         Reggie Evans      700000
# 12           Ansu Sesay      688679
# 13        Ronald Murray      563679
# 14         Richie Frahm      366931
# 15               Totals    52347476
#            player_names  salary ($)
# 0           Gary Payton    12636117
# 1        Kenny Anderson     9185000
# 2         Rashard Lewis     6233766
# 3      Vitaly Potapenko     5238750
# 4           Brent Barry     5040000
# 5          Calvin Booth     4992900
# 6          Jerome James     4546000
# 7   Vladimir Radmanovic     1560840
# 8         Desmond Mason     1235880
# 9          Joseph Forte     1009920
# 10           Ansu Sesay      612435
# 11     Predrag Drobnjak      526413
# 12         Reggie Evans      349458
# 13               Totals    53167479
#            player_names  salary ($)
# 0           Gary Payton    12926493
# 1             Vin Baker    11250000
# 2           Brent Barry     4680000
# 3          Calvin Booth     4539000
# 4         Rashard Lewis     4413375
# 5     Shammond Williams     1750000
# 6   Vladimir Radmanovic     1452000
# 7         Desmond Mason     1155240
# 8        Antonio Harvey      715850
# 9      Predrag Drobnjak      478558
# 10             Art Long      465850
# 11         Jerome James      465850
# 12      Olumide Oyedeji      465850
# 13     Ruben Wolkowyski      465850
# 14          Earl Watson      332817
# 15               Totals    45556733
#          player_names  salary ($)
# 0         Paul George    35450412
# 1       Kawhi Leonard    34379100
# 2       Marcus Morris    14883721
# 3    Patrick Beverley    13333333
# 4         Serge Ibaka     9258000
# 5         Rajon Rondo     7500000
# 6         Ivica Zubac     7000000
# 7        Luke Kennard     5273826
# 8   Patrick Patterson     3077704
# 9       Nicolas Batum     2564753
# 10     Reggie Jackson     2331593
# 11       Terance Mann     1517981
# 12       Daniel Oturu      898310
# 13   DeMarcus Cousins      720239
# 14        Amir Coffey      578842
# 15         Jay Scrubb      449115
# 16       Yogi Ferrell      444149
# 17        Malik Fitts       61528
# 18             Totals   139722606
#          player_names  salary ($)
# 0         Paul George    33005556
# 1       Kawhi Leonard    32742000
# 2       Marcus Morris    15000000
# 3    Patrick Beverley    12345680
# 4      Louis Williams     8000000
# 5         Ivica Zubac     6481482
# 6    Montrezl Harrell     6000000
# 7     Rodney McGruder     4807693
# 8      JaMychal Green     4767000
# 9   Patrick Patterson     2331593
# 10      Landry Shamet     1995120
# 11  Mfiondu Kabengele     1977000
# 12       Terance Mann     1000000
# 13     Reggie Jackson      512721
# 14        Joakim Noah      381360
# 15   Johnathan Motley       79568
# 16        Amir Coffey       79568
# 17             Totals   131506341
#                player_names  salary ($)
# 0          Danilo Gallinari    21587579
# 1             Marcin Gortat    13565218
# 2           Wilson Chandler    12800562
# 3            JaMychal Green     8066667
# 4            Louis Williams     8000000
# 5            Garrett Temple     8000000
# 6            Milos Teodosic     6300000
# 7          Montrezl Harrell     6000000
# 8             Alexis Ajinca     5285394
# 9          Patrick Beverley     5027028
# 10         Luc Mbah a Moute     4320500
# 11          Michael Beasley     3500000
# 12  Shai Gilgeous-Alexander     3375360
# 13          Jerome Robinson     3050160
# 14            Landry Shamet     1705920
# 15              Ivica Zubac     1544951
# 16          Rodney McGruder     1544951
# 17              Jawun Evans     1378242
# 18      Sindarius Thornwell     1378242
# 19           Tyrone Wallace     1349383
# 20             Justin Bibbs       92159
# 21            Angel Delgado       77250
# 22         Johnathan Motley       77250
# 23                   Totals   118026816
#            player_names  salary ($)
# 0        DeAndre Jordan    22642350
# 1      Danilo Gallinari    20559599
# 2         Tobias Harris    16000000
# 3         Austin Rivers    11825000
# 4         Avery Bradley     8808989
# 5        Louis Williams     7000000
# 6        Milos Teodosic     6000000
# 7        Wesley Johnson     5881260
# 8      Boban Marjanovic     5881260
# 9      Patrick Beverley     5513514
# 10          Paul Pierce     3679840
# 11           Sam Dekker     1794600
# 12     Montrezl Harrell     1471382
# 13          Jawun Evans      815615
# 14  Sindarius Thornwell      815615
# 15      Sean Kilpatrick      172236
# 16         Jamil Wilson       77250
# 17          CJ Williams       77250
# 18       Tyrone Wallace       77250
# 19               Totals   119093010
#          player_names  salary ($)
# 0          Chris Paul    22868827
# 1      DeAndre Jordan    21165675
# 2       Blake Griffin    20093064
# 3      Jamal Crawford    13253012
# 4       Austin Rivers    11000000
# 5           JJ Redick     7377500
# 6      Wesley Johnson     5628000
# 7         Paul Pierce     3527920
# 8    Luc Mbah a Moute     2203000
# 9      Raymond Felton     1551659
# 10       Brandon Bass     1551659
# 11  Marreese Speights     1403611
# 12      Alan Anderson     1315448
# 13      Brice Johnson     1273920
# 14      Diamond Stone      543471
# 15             Totals   114756766
#         player_names  salary ($)
# 0         Chris Paul    21468695
# 1     DeAndre Jordan    19689000
# 2      Blake Griffin    18862876
# 3         Jeff Green     9200000
# 4          JJ Redick     7085000
# 5     Jamal Crawford     5675000
# 6        Paul Pierce     3376000
# 7      Austin Rivers     3110796
# 8      Jordan Farmar     2100000
# 9   Luc Mbah a Moute     1270964
# 10         CJ Wilcox     1159680
# 11      Cole Aldrich     1100602
# 12    Wesley Johnson     1100602
# 13    Pablo Prigioni      981348
# 14    Branden Dawson      525093
# 15        Jeff Ayres      251890
# 16    Alex Stepheson       61775
# 17            Totals    97019321
#           player_names  salary ($)
# 0           Chris Paul    20068563
# 1        Blake Griffin    17632688
# 2       DeAndre Jordan    11440123
# 3            JJ Redick     6792500
# 4       Jamal Crawford     5450000
# 5        Spencer Hawes     5305000
# 6          Matt Barnes     3396250
# 7       Carlos Delfino     3250000
# 8        Austin Rivers     2439840
# 9        Jordan Farmar     2100000
# 10  Miroslav Raduljica     1500000
# 11    Hidayet Turkoglu     1448490
# 12          Glen Davis     1227985
# 13           CJ Wilcox     1109760
# 14           Ekpe Udoh      981084
# 15       Dahntay Jones      721169
# 16     Jordan Hamilton      284447
# 17       Lester Hudson      111548
# 18              Totals    85259447
#         player_names  salary ($)
# 0         Chris Paul    18668431
# 1      Blake Griffin    16402500
# 2     DeAndre Jordan    10986550
# 3          JJ Redick     6500000
# 4     Jamal Crawford     5225000
# 5       Jared Dudley     4250000
# 6        Matt Barnes     3250000
# 7    Darren Collison     1900000
# 8       Willie Green     1399507
# 9       Ryan Hollins     1186459
# 10    Reggie Bullock     1149000
# 11  Hidayet Turkoglu      650359
# 12      Maalik Wayns      361952
# 13     Danny Granger      357452
# 14        Glen Davis      350000
# 15   Stephen Jackson      238739
# 16     Darius Morris      104034
# 17     Sasha Vujacic       69791
# 18            Totals    73049774
#         player_names  salary ($)
# 0         Chris Paul    17779457
# 1     DeAndre Jordan    10532977
# 2         Lamar Odom     8200000
# 3       Caron Butler     8000000
# 4      Blake Griffin     7226891
# 5     Jamal Crawford     5000000
# 6         Ryan Gomes     4000000
# 7   Chauncey Billups     3000000
# 8         Grant Hill     1957000
# 9       Eric Bledsoe     1707720
# 10      Willie Green     1375000
# 11      Ronny Turiaf     1146337
# 12      Ryan Hollins     1069509
# 13       Matt Barnes      854389
# 14    Trey Thompkins      762195
# 15     Travis Leslie      250000
# 16    DaJuan Summers      177024
# 17      Maalik Wayns      114222
# 18            Totals    69152721
#         player_names  salary ($)
# 0         Chris Paul    16359805
# 1     DeAndre Jordan    10079404
# 2   Maurice Williams     8500000
# 3       Caron Butler     8000000
# 4      Blake Griffin     5731080
# 5         Randy Foye     4250000
# 6         Ryan Gomes     4000000
# 7      Kenyon Martin     2500000
# 8   Chauncey Billups     2000032
# 9       Eric Bledsoe     1596360
# 10      Reggie Evans     1229255
# 11        Brian Cook     1223166
# 12     Bobby Simmons      594836
# 13     Travis Leslie      473604
# 14    Trey Thompkins      473604
# 15     Solomon Jones      280234
# 16  Courtney Fortson       42009
# 17            Totals    67333389
# 50
#         player_names  salary ($)
# 0        Chris Kaman    11800000
# 1   Maurice Williams     9300000
# 2      Blake Griffin     5357280
# 3         Randy Foye     4250000
# 4         Ryan Gomes     4000000
# 5        Eric Gordon     3016680
# 6       Jamario Moon     3000000
# 7    Al-Farouq Aminu     2563320
# 8      Rasual Butler     2400000
# 9        Craig Smith     2300000
# 10      Eric Bledsoe     1485000
# 11        Brian Cook     1146337
# 12    DeAndre Jordan      854389
# 13    Jarron Collins      643551
# 14         Ike Diogu      608772
# 15     Willie Warren      500000
# 16            Totals    53225329
#       player_names  salary ($)
# 0      Baron Davis    12150000
# 1      Chris Kaman    10400000
# 2    Blake Griffin     4983480
# 3      Steve Blake     4930000
# 4      Drew Gooden     4500000
# 5    Travis Outlaw     4000000
# 6    Rasual Butler     3945000
# 7      Mark Madsen     2840000
# 8      Eric Gordon     2819880
# 9      Craig Smith     2500000
# 10     Ricky Davis     2484000
# 11   Mardy Collins     1867742
# 12   Brian Skinner     1306455
# 13     Steve Novak      855189
# 14  DeAndre Jordan      736420
# 15     Bobby Brown      736420
# 16     Kareem Rush      534906
# 17   JamesOn Curry       26917
# 18          Totals    61616409
#       player_names  salary ($)
# 0    Zach Randolph    14666667
# 1      Baron Davis    11250000
# 2     Marcus Camby    10000000
# 3      Chris Kaman     9500000
# 4      Eric Gordon     2623200
# 5       Jason Hart     2484000
# 6      Ricky Davis     2300000
# 7      Al Thornton     1776240
# 8    Brian Skinner     1262275
# 9   Jason Williams     1262275
# 10   Mardy Collins     1034760
# 11     Steve Novak      797581
# 12     Cheikh Samb      797581
# 13      Alex Acker      711517
# 14      Fred Jones      622531
# 15  DeAndre Jordan      550000
# 16     Mike Taylor      500000
# 17      Paul Davis      328416
# 18    Hassan Adams      297163
# 19          Totals    62764206
#         player_names  salary ($)
# 0        Elton Brand    15344000
# 1        Chris Kaman     8600000
# 2     Cuttino Mobley     8350000
# 3     Corey Maggette     7000000
# 4        Sam Cassell     6150000
# 5         Tim Thomas     5632200
# 6   Shaun Livingston     4404629
# 7     Aaron Williams     1890000
# 8        Al Thornton     1652280
# 9      Brevin Knight     1600000
# 10        Dan Dickau      926678
# 11      Quinton Ross      826046
# 12       Josh Powell      800000
# 13        Paul Davis      687456
# 14      Richie Frahm      623694
# 15   Ruben Patterson      304897
# 16    Guillermo Diaz       56065
# 17            Totals    64847945
#         player_names  salary ($)
# 0        Elton Brand    14248000
# 1     Cuttino Mobley     8125000
# 2     Corey Maggette     7000000
# 3        Sam Cassell     6850000
# 4         Tim Thomas     5215000
# 5        Chris Kaman     3491768
# 6   Shaun Livingston     3481920
# 7     Zeljko Rebraca     3240000
# 8   Yaroslav Korolev     1832280
# 9     Aaron Williams     1750000
# 10   Boniface N'Dong      839209
# 11      Quinton Ross      771331
# 12   James Singleton      675000
# 13      Daniel Ewing      664209
# 14        Paul Davis      412718
# 15        Jason Hart      242640
# 16     Doug Christie      158071
# 17    Alvin Williams      103992
# 18      Luke Jackson       40501
# 19         Von Wafer       24300
# 20       Will Conroy       15099
# 21            Totals    59181038
#         player_names  salary ($)
# 0        Elton Brand    13152000
# 1     Cuttino Mobley     7200000
# 2     Corey Maggette     7000000
# 3        Sam Cassell     6875000
# 4   Shaun Livingston     3254880
# 5     Zeljko Rebraca     3000000
# 6       Chris Wilcox     2812239
# 7        Chris Kaman     2753760
# 8   Yaroslav Korolev     1704480
# 9     Walter McCarty     1035000
# 10      Quinton Ross      700000
# 11   James Singleton      625000
# 12      Daniel Ewing      450000
# 13   Boniface N'Dong      398762
# 14     Howard Eisley      291567
# 15  Anthony Goldwire       74652
# 16    Kaniel Dickens       31305
# 17            Totals    51358645
#         player_names  salary ($)
# 0        Elton Brand    12056000
# 1      Kerry Kittles     9566667
# 2     Corey Maggette     7000000
# 3   Shaun Livingston     3027840
# 4        Chris Kaman     2574240
# 5     Zeljko Rebraca     2500000
# 6       Chris Wilcox     2210880
# 7        Marko Jaric     2100000
# 8       Rick Brunson      932546
# 9        Mikki Moore      870046
# 10     Bobby Simmons      825000
# 11   Mamadou N'diaye      750000
# 12      Quinton Ross      620046
# 13   Lionel Chalmers      450000
# 14            Totals    45483265
#           player_names  salary ($)
# 0          Elton Brand    10960000
# 1       Corey Maggette     7000000
# 2     Predrag Drobnjak     2500000
# 3          Chris Kaman     2394600
# 4        Keyon Dooling     2256444
# 5          Wang Zhizhi     2090000
# 6         Chris Wilcox     2066760
# 7          Marko Jaric     1925000
# 8   Quentin Richardson     1805735
# 9           Melvin Ely     1628760
# 10           Glen Rice     1070000
# 11      Olden Polynice     1070000
# 12         Eddie House      750000
# 13       Bobby Simmons      638679
# 14        Doug Overton      591454
# 15          Josh Moore      366931
# 16              Totals    39114363
#           player_names  salary ($)
# 0   Michael Olowokandi     6061213
# 1          Elton Brand     4895656
# 2         Derek Strong     4212000
# 3           Lamar Odom     3557585
# 4      Eric Piatkowski     3000000
# 5           Sean Rooks     2640000
# 6         Andre Miller     2460709
# 7       Corey Maggette     2069764
# 8         Bryant Stith     2000000
# 9         Chris Wilcox     1922520
# 10         Wang Zhizhi     1900000
# 11       Keyon Dooling     1769760
# 12         Marko Jaric     1750000
# 13          Melvin Ely     1490120
# 14  Quentin Richardson     1174080
# 15      Cherokee Parks      824935
# 16        Earl Boykins      715000
# 17    Tremaine Fowlkes      512435
# 18              Totals    42955777
#           player_names  salary ($)
# 0   Michael Olowokandi     4662472
# 1          Elton Brand     3882360
# 2         Derek Strong     3861000
# 3         Darius Miles     3054840
# 4      Eric Piatkowski     3000000
# 5           Lamar Odom     2812320
# 6           Sean Rooks     2400000
# 7      Vinny Del Negro     2275000
# 8        Keyon Dooling     1654320
# 9       Corey Maggette     1448400
# 10         Will Perdue     1320000
# 11  Quentin Richardson     1097520
# 12        Earl Boykins      650000
# 13      Harold Jamison      600000
# 14        Jeff McInnis      590850
# 15       Obinna Ekezie      540850
# 16              Totals    33849932
#            player_names   salary ($)
# 0            Kevin Love   31258256.0
# 1        Andre Drummond   27957238.0
# 2        Taurean Prince   12250000.0
# 3        Larry Nance Jr   11709091.0
# 4            Cedi Osman    8840580.0
# 5        Darius Garland    6720720.0
# 6           Isaac Okoro    6400920.0
# 7         Collin Sexton    4991880.0
# 8         Jarrett Allen    3909902.0
# 9   Matthew Dellavedova    2174318.0
# 10        Dylan Windler    2137440.0
# 11       Damyean Dotson    2000000.0
# 12           Thon Maker    1737145.0
# 13   Isaiah Hartenstein    1620564.0
# 14            Dean Wade    1517981.0
# 15             JR Smith    1456667.0
# 16        Lamar Stevens    1000000.0
# 17       Marques Bolden     449115.0
# 18    Mfiondu Kabengele     356473.0
# 19        Rayjon Tucker     340000.0
# 20       Brodric Thomas     252243.0
# 21           Quinn Cook     237966.0
# 22     Anderson Varejao     228368.0
# 23      Jeremiah Martin      58452.0
# 24         JaVale McGee          NaN
# 25            129605319  136592914.0
#            player_names  salary ($)
# 0            Kevin Love    28942830
# 1        Andre Drummond    27093018
# 2      Tristan Thompson    18539130
# 3        Larry Nance Jr    12727273
# 4   Matthew Dellavedova     9607500
# 5            Dante Exum     9600000
# 6        Darius Garland     6400920
# 7         Collin Sexton     4764960
# 8            Cedi Osman     2907143
# 9      Alfonzo McKinnie     2391985
# 10           Ante Zizic     2281800
# 11        Dylan Windler     2035800
# 12             JR Smith     1456667
# 13         Kevin Porter     1290960
# 14            Dean Wade      375000
# 15          Jordan Bell      250000
# 16            JP Macura      106181
# 17          Sheldon Mac       91557
# 18          Matt Mooney       79568
# 19         Malik Newman       65978
# 20  Sir'Dominic Pointer       50752
# 21               Totals   131059022
#            player_names  salary ($)
# 0            Kevin Love    24119025
# 1      Tristan Thompson    17469565
# 2              JR Smith    14720000
# 3        Brandon Knight    14631250
# 4       Jordan Clarkson    12500000
# 5           John Henson    10577466
# 6   Matthew Dellavedova     9607500
# 7         Collin Sexton     4073760
# 8       Marquese Chriss     3206160
# 9            Cedi Osman     2775000
# 10        Channing Frye     2393887
# 11       Larry Nance Jr     2272390
# 12           Ante Zizic     1952760
# 13          David Nwaba     1512601
# 14         Nik Stauskas      540471
# 15        Patrick McCaw      186440
# 16        Cameron Payne      177062
# 17         John Holland       77250
# 18        Billy Preston       77250
# 19      Andrew Harrison       77250
# 20    Jaron Blossomgame       77250
# 21          Jalen Jones       77250
# 22            Deng Adel       77250
# 23         Kobi Simmons       76236
# 24               Totals   123255073
#           player_names  salary ($)
# 0         LeBron James    33285709
# 1           Kevin Love    22642350
# 2          George Hill    20000000
# 3     Tristan Thompson    16400000
# 4             JR Smith    13760000
# 5      Jordan Clarkson    11562500
# 6          Kyle Korver     7000000
# 7           Cedi Osman     2642857
# 8          Rodney Hood     2386864
# 9        Jose Calderon     2328652
# 10          Jeff Green     2116955
# 11          Ante Zizic     1645200
# 12      Larry Nance Jr     1471382
# 13         Okaro White      148316
# 14    Kendrick Perkins      131562
# 15        John Holland       77250
# 16    London Perrantes       77250
# 17  Marcus Thornton II       46079
# 18              Totals   137722926
#          player_names  salary ($)
# 0        LeBron James    30963450
# 1          Kevin Love    21165675
# 2        Kyrie Irving    17638063
# 3    Tristan Thompson    15330435
# 4            JR Smith    12800000
# 5       Iman Shumpert     9662922
# 6       Channing Frye     7806971
# 7         Kyle Korver     5239437
# 8   Richard Jefferson     2500000
# 9         James Jones     1551659
# 10    DeAndre Liggins      991797
# 11       Jordan McRae      874636
# 12         Kay Felder      543471
# 13   Derrick Williams      422145
# 14     Deron Williams      410733
# 15       Andrew Bogut      383351
# 16      Larry Sanders      207722
# 17      Dahntay Jones       24022
# 18     Walter Tavares        6000
# 19             Totals   128522489
#            player_names  salary ($)
# 0          LeBron James    22970500
# 1            Kevin Love    19689000
# 2          Kyrie Irving    16407500
# 3      Tristan Thompson    14260000
# 4         Iman Shumpert     8988765
# 5         Channing Frye     8193029
# 6              JR Smith     5000000
# 7        Timofey Mozgov     4950000
# 8      Maurice Williams     2100000
# 9           James Jones     1499187
# 10    Richard Jefferson     1499187
# 11  Matthew Dellavedova     1347276
# 12           Sasha Kaun     1276000
# 13         Jordan McRae      111196
# 14        Dahntay Jones        8818
# 15               Totals   108300458
#            player_names  salary ($)
# 0          LeBron James    20644400
# 1            Kevin Love    15719063
# 2      Anderson Varejao     9800000
# 3          Kyrie Irving     7459924
# 4              JR Smith     5982375
# 5      Tristan Thompson     5421233
# 6        Timofey Mozgov     4650000
# 7         Iman Shumpert     2761113
# 8           Mike Miller     2732000
# 9       Brendan Haywood     2000000
# 10          James Jones     1448490
# 11         Shawn Marion     1448490
# 12           Joe Harris      884879
# 13  Matthew Dellavedova      816482
# 14     Kendrick Perkins      434547
# 15             AJ Price      283264
# 16          Will Cherry      106567
# 17               Totals    82592827
#            player_names  salary ($)
# 0             Luol Deng    14312125
# 1      Anderson Varejao     9100000
# 2         Spencer Hawes     6500000
# 3          Jarrett Jack     6300000
# 4          Kyrie Irving     5915880
# 5       Anthony Bennett     5324280
# 6      Tristan Thompson     4285560
# 7          Dion Waiters     3894240
# 8            Alonzo Gee     3250000
# 9              CJ Miles     2225000
# 10         Tyler Zeller     1633440
# 11       Sergey Karasev     1467840
# 12        Scotty Hopson     1350000
# 13  Matthew Dellavedova      490180
# 14        Carrick Felix      490180
# 15        Arinze Onuaku       57668
# 16           Seth Curry       28834
# 17        Shane Edwards       28834
# 18               Totals    66654061
#          player_names  salary ($)
# 0         Baron Davis    14850000
# 1    Anderson Varejao     8400000
# 2         Luke Walton     6091363
# 3        Kyrie Irving     5530080
# 4       Daniel Gibson     4792332
# 5   Marreese Speights     4200000
# 6    Tristan Thompson     4006080
# 7        Dion Waiters     3726600
# 8          Alonzo Gee     3500000
# 9         Omri Casspi     2277306
# 10           CJ Miles     2225000
# 11    Wayne Ellington     2083042
# 12       Tyler Zeller     1563120
# 13     Luke Harangody     1054389
# 14       Jeremy Pargo     1000000
# 15   Kelenna Azubuike      992680
# 16   Shaun Livingston      806323
# 17         Josh Selby      762195
# 18        Kevin Jones      390000
# 19    Samardo Samuels      346781
# 20       Micheal Eric      300000
# 21       Donald Sloan      255560
# 22        Chris Quinn      169339
# 23             Totals    54472190
#         player_names  salary ($)
# 0     Antawn Jamison    15076715
# 1        Baron Davis    13900000
# 2   Anderson Varejao     7700000
# 3       Kyrie Irving     5144280
# 4      Daniel Gibson     4403834
# 5     Ramon Sessions     4257973
# 6   Tristan Thompson     3726600
# 7       Ryan Hollins     2483333
# 8     Anthony Parker     2250000
# 9        Omri Casspi     1341960
# 10  Christian Eyenga     1097520
# 11        Alonzo Gee      854389
# 12       Semih Erden      762195
# 13   Samardo Samuels      762195
# 14    Luke Harangody      762195
# 15   Mychel Thompson      168035
# 16      Manny Harris      122942
# 17          Ben Uzoh       61433
# 18            Totals    64875599
#         player_names  salary ($)
# 0     Antawn Jamison    13358905
# 1        Baron Davis    13000000
# 2   Anderson Varejao     7281818
# 3      Daniel Gibson     4015334
# 4     Ramon Sessions     3964320
# 5     Anthony Parker     2855700
# 6       Ryan Hollins     2333333
# 7         JJ Hickson     1528920
# 8   Christian Eyenga     1020960
# 9        Joey Graham      992680
# ...
# 17       Tarence Kinsey      219533
# 18          Bobby Jones       85932
# 19               Totals    54118526
#          player_names  salary ($)
# 0         Eddie Jones    14863778
# 1           Pau Gasol    12364000
# 2         Mike Miller     7623813
# 3      Brian Cardinal     5400000
# 4      Stromile Swift     5400000
# 5    Damon Stoudamire     4050000
# 6       Chucky Atkins     3000000
# 7            Rudy Gay     2242290
# 8       Dahntay Jones     1886113
# 9       Hakim Warrick     1286280
# 10         Kyle Lowry     1011720
# 11      Scott Padgett      932015
# 12   Lawrence Roberts      664209
# 13  Alexander Johnson      412718
# 14     Tarence Kinsey      412718
# 15  Junior Harrington      390556
# 16        Will Conroy       20279
# 17             Totals    61960489
# 575
#           player_names  salary ($)
# 0          Eddie Jones    14576250
# 1            Pau Gasol    10993000
# 2      Lorenzen Wright     7700000
# 3          Mike Miller     6750000
# 4       Brian Cardinal     5393300
# 5        Shane Battier     4903000
# 6     Damon Stoudamire     3750000
# 7        Bobby Jackson     3375000
# 8   Iakovos Tsakalidis     2900000
# 9           Raul Lopez     1744313
# 10           Troy Bell     1478280
# 11       Dahntay Jones     1223160
# 12       Hakim Warrick     1196520
# 13       Antonio Burks      641748
# 14    Anthony Roberson      398762
# 15    Lawrence Roberts      398762
# 16         John Thomas      103443
# 17              Totals    67525538
#           player_names  salary ($)
# 0          Bonzi Wells     7700000
# 1      Lorenzen Wright     7150000
# 2       Jason Williams     6875000
# 3            Bo Outlaw     6573148
# 4          Mike Miller     6000000
# 5       Stromile Swift     5993105
# 6          James Posey     5408700
# 7       Brian Cardinal     4903000
# 8            Pau Gasol     4318481
# 9        Shane Battier     3212402
# 10  Iakovos Tsakalidis     2900000
# 11         Earl Watson     1458000
# 12           Troy Bell     1381920
# 13       Ryan Humphrey     1223160
# 14       Dahntay Jones     1143360
# 15        Andre Emmett      385277
# 16       Antonio Burks      385277
# 17              Totals    67010830
#           player_names  salary ($)
# 0          Bonzi Wells     7000000
# 1      Lorenzen Wright     6600000
# 2            Bo Outlaw     6585000
# 3       Jason Williams     6187500
# 4    Michael Dickerson     6187500
# 5          James Posey     4917000
# 6       Stromile Swift     4592418
# 7          Mike Miller     3380457
# 8            Pau Gasol     2618395
# 9        Shane Battier     2533440
# 10  Iakovos Tsakalidis     1580702
# 11         Earl Watson     1336500
# 12           Troy Bell     1285440
# 13       Ryan Humphrey     1143360
# 14       Dahntay Jones     1063680
# 15        Theron Smith      366931
# 16              Totals    57378323
#          player_names  salary ($)
# 0       Bryant Reeves    12999998
# 1       Wesley Person     7000000
# 2     Lorenzen Wright     6050000
# 3      Jason Williams     5500000
# 4   Michael Dickerson     5500000
# 5       Brevin Knight     5000000
# 6      Stromile Swift     3639000
# 7           Pau Gasol     3193680
# 8         Drew Gooden     2794920
# 9       Shane Battier     2368200
# 10    Tony Massenburg     1800000
# 11   Cezary Trybanski     1500000
# 12     Gordan Giricek     1400000
# 13        Earl Watson     1215000
# 14        Chris Owens      349458
# 15       Mike Batiste      349458
# 16   Robert Archibald      349458
# 17             Totals    61009172
#          player_names  salary ($)
# 0       Bryant Reeves    11555554
# 1        Isaac Austin     5695715
# 2     Lorenzen Wright     5500000
# 3       Nick Anderson     5401906
# 4       Brevin Knight     4500000
# 5      Stromile Swift     3401640
# 6           Pau Gasol     2970840
# 7      Jason Williams     2554072
# 8          Grant Long     2400000
# 9       Shane Battier     2203080
# 10  Michael Dickerson     1940702
# 11    Tony Massenburg     1650000
# 12      Rodney Buford      481488
# 13     Antonis Fotsis      332817
# 14     Willie Solomon      332817
# 15             Totals    50920631
#        player_names  salary ($)
# 0    Gordon Hayward    28500000
# 1      Terry Rozier    18900000
# 2       Cody Zeller    15415730
# 3     Nicolas Batum     9043478
# 4       LaMelo Ball     7839960
# 5        Malik Monk     5345687
# 6     PJ Washington     4023600
# 7     Miles Bridges     3934320
# 8   Bismack Biyombo     3500000
# 9    Brad Wanamaker     2250000
# 10   Devonte Graham     1663861
# 11      Cody Martin     1517981
# 12     Caleb Martin     1517981
# 13  Jalen McDaniels     1517981
# 14     Vernon Carey     1350000
# 15    Nick Richards     1000000
# 16     Grant Riller      449115
# 17     Nate Darling      449115
# 18           Totals   108218809
#          player_names  salary ($)
# 0       Nicolas Batum    25565217
# 1        Terry Rozier    19894737
# 2     Bismack Biyombo    17000000
# 3         Cody Zeller    14471910
# 4          Malik Monk     4028400
# 5       PJ Washington     3831840
# 6       Miles Bridges     3755400
# 7   Willy Hernangomez     1676735
# 8        Dwayne Bacon     1618520
# 9      Devonte Graham     1416852
# 10        Cody Martin     1173310
# 11    Jalen McDaniels      898310
# 12       Caleb Martin      898310
# 13        Joe Chealey      163356
# 14   Raymond Spalding       79568
# 15       Kobi Simmons       79568
# 16             Totals    96552033
#               player_names  salary ($)
# 0            Nicolas Batum    24000000
# 1          Bismack Biyombo    17000000
# 2          Marvin Williams    14087500
# 3              Cody Zeller    13528090
# 4   Michael Kidd-Gilchrist    13000000
# 5             Kemba Walker    12000000
# 6              Jeremy Lamb     7000000
# 7              Tony Parker     5000000
# 8           Frank Kaminsky     3627842
# 9               Malik Monk     3447480
# 10           Miles Bridges     3206640
# 11            Shelvin Mack     1512601
# 12       Willy Hernangomez     1496500
# 13            Dwayne Bacon     1378242
# 14          Devonte Graham      988464
# 15               JP Macura       77250
# 16             Joe Chealey       77250
# 17                  Totals   121427859
#                player_names  salary ($)
# 0             Dwight Howard    23500000
# 1             Nicolas Batum    22434783
# 2           Marvin Williams    13168750
# 3    Michael Kidd-Gilchrist    13000000
# 4               Cody Zeller    12584270
# 5              Kemba Walker    12000000
# 6               Jeremy Lamb     7000000
# 7                Malik Monk     2904480
# 8            Frank Kaminsky     2847600
# 9   Michael Carter-Williams     2700000
# 10             Julyan Stone     1524305
# 11        Willy Hernangomez     1435750
# 12           Treveon Graham     1312611
# 13             Dwayne Bacon      815615
# 14          Mangok Mathiang       77250
# 15             Marcus Paige       77250
# 16                   Totals   117382664
#               player_names  salary ($)
# 0            Nicolas Batum    20869566
# 1   Michael Kidd-Gilchrist    13000000
# 2            Miles Plumlee    12400000
# 3          Marvin Williams    12250000
# 4             Kemba Walker    12000000
# 5              Jeremy Lamb     7000000
# 6          Marco Belinelli     6333333
# 7           Ramon Sessions     6000000
# 8              Cody Zeller     5318313
# 9           Frank Kaminsky     2730000
# 10          Chris Andersen     1551659
# 11           Brian Roberts     1050961
# 12          Christian Wood      874636
# 13          Treveon Graham      543471
# 14          Aaron Harrison      365289
# 15         Johnny O'Bryant      276825
# 16           Briante Weber      231521
# 17              Mike Tobey      138937
# 18            Ray McCallum      119493
# 19                  Totals   103054004
#               player_names  salary ($)
# 0             Al Jefferson    13500000
# 1             Kemba Walker    12000000
# 2            Nicolas Batum    11860750
# 3          Marvin Williams     7000000
# 4   Michael Kidd-Gilchrist     6331403
# 5             Courtney Lee     5675000
# 6            Spencer Hawes     5543725
# 7              Cody Zeller     4204200
# 8              Jeremy Lamb     3034356
# 9           Frank Kaminsky     2612520
# 10              Jeremy Lin     2139000
# 11        Tyler Hansbrough     1185784
# 12            Troy Daniels      947276
# 13          Aaron Harrison      525093
# 14         Jorge Gutierrez      300899
# 15                  Totals    76860006
#               player_names  salary ($)
# 0             Al Jefferson    13500000
# 1             Tyrus Thomas     9388430
# 2         Lance Stephenson     9000000
# 3          Marvin Williams     7000000
# 4         Gerald Henderson     6000000
# 5   Michael Kidd-Gilchrist     5016960
# 6          Bismack Biyombo     4086453
# 7              Cody Zeller     4030560
# 8         Maurice Williams     3750000
# 9             Kemba Walker     3452183
# 10           Brian Roberts     2732000
# 11             Noah Vonleh     2524200
# 12           Jannero Pargo     1448490
# 13           Jason Maxiell     1316809
# 14             PJ Hairston     1149720
# 15          Jeffery Taylor      915243
# 16            Troy Daniels      816482
# 17         Elliot Williams       53837
# 18                  Totals    66792937
#               player_names  salary ($)
# 0             Al Jefferson    13500000
# 1               Ben Gordon    13200000
# 2             Tyrus Thomas     8694215
# 3         Gerald Henderson     6000000
# 4   Michael Kidd-Gilchrist     4809840
# 5             Luke Ridnour     4320000
# 6              Cody Zeller     3857040
# 7                Gary Neal     3250000
# 8          Bismack Biyombo     3217680
# 9             Kemba Walker     2709720
# 10          Josh McRoberts     2652000
# 11           Jannero Pargo     1399507
# 12          Jeffery Taylor      788872
# 13   Chris Douglas-Roberts      535288
# 14       James Southerland      126870
# 15         Justin Hamilton       28834
# 16                  Totals    60395651
#               player_names  salary ($)
# 0               Ben Gordon    12400000
# 1             Tyrus Thomas     8000000
# 2            DeSagana Diop     7372200
# 3           Ramon Sessions     5000000
# 4   Michael Kidd-Gilchrist     4602720
# 5           Josh McRoberts     3135000
# 6         Gerald Henderson     3101326
# 7          Bismack Biyombo     3007920
# 8             Kemba Walker     2532960
# 9          Reggie Williams     2500000
# 10              BJ Mullens     2253061
# 11         Brendan Haywood     2000000
# 12            Cory Higgins      762195
# 13             Jeff Adrien      653356
# 14          Jeffery Taylor      550000
# 15           Jannero Pargo      251828
# 16                  Totals    58122566
#         player_names  salary ($)
# 0     Corey Maggette    10262069
# 1         Boris Diaw     9000000
# 2       Tyrus Thomas     7305765
# 3      DeSagana Diop     6925400
# 4       Matt Carroll     3900000
# 5        DJ Augustin     3236470
# 6    Bismack Biyombo     2798040
# 7     Eduardo Najera     2750000
# 8    Reggie Williams     2500000
# 9       Kemba Walker     2356320
# 10  Gerald Henderson     2250600
# 11          DJ White     2001167
# 12        BJ Mullens     1288200
# 13     Derrick Brown      854389
# 14      Cory Higgins      473604
# 15            Totals    57902024
#         player_names  salary ($)
# 0         Boris Diaw     9000000
# 1    Stephen Jackson     8453250
# 2     Joel Przybilla     7405300
# 3    Morris Peterson     6665000
# 4       Tyrus Thomas     6611570
# 5      DeSagana Diop     6478600
# 6       Matt Carroll     4300000
# 7   Shaun Livingston     3500000
# 8     Eduardo Najera     3000000
# 9        DJ Augustin     2540400
# 10  Gerald Henderson     2103840
# 11        Sean Marks     1264687
# 12       Kwame Brown     1229255
# 13          DJ White     1108680
# 14   Dominic McGuire      884120
# 15  Dante Cunningham      762195
# 16     Derrick Brown      762195
# 17   Sherron Collins      473604
# 18            Totals    66542696
#         player_names  salary ($)
# 0     Tyson Chandler    11850000
# 1     Gerald Wallace     9075000
# 2         Boris Diaw     9000000
# 3    Stephen Jackson     7650000
# 4      Nazr Mohammed     6466600
# 5      DeSagana Diop     6031800
# 6     Raymond Felton     5501196
# 7       Tyrus Thomas     4743598
# 8        DJ Augustin     2385480
# 9   Gerald Henderson     1957080
# 10     Alexis Ajinca     1372080
# 11      Theo Ratliff     1306455
# 12    Stephen Graham      884881
# 13     Derrick Brown      457588
# 14            Totals    68681758
#            player_names  salary ($)
# 0          Emeka Okafor     9537500
# 1        Gerald Wallace     9500000
# 2            Boris Diaw     9000000
# 3         Nazr Mohammed     6049400
# 4   Vladimir Radmanovic     6049400
# 5         DeSagana Diop     5585000
# 6             Raja Bell     5000000
# 7        Raymond Felton     4148716
# 8              Sean May     2661027
# 9           DJ Augustin     2208960
# 10        Alexis Ajinca     1276320
# 11         Juwan Howard      928143
# 12      Sean Singletary      442114
# 13       Cartier Martin      200252
# 14       Linton Johnson      125374
# 15          Andre Brown      107908
# 16         Dwayne Jones       46812
# 17               Totals    62866926
#           player_names  salary ($)
# 0     Jason Richardson    11111110
# 1       Gerald Wallace     9500000
# 2        Nazr Mohammed     5632200
# 3         Matt Carroll     5450000
# 4         Emeka Okafor     5427307
# 5        Adam Morrison     3887880
# 6       Raymond Felton     3274440
# 7   Othella Harrington     2376000
# 8             Sean May     1862160
# 9       Derek Anderson     1219590
# 10        Jeff McInnis     1219590
# 11        Jared Dudley     1137000
# 12        Ryan Hollins      687456
# 13        Earl Boykins      533572
# 14   Jermareo Davidson      427163
# 15              Totals    53745468
#           player_names  salary ($)
# 0       Gerald Wallace     5525000
# 1        Brevin Knight     4400000
# 2         Emeka Okafor     4300560
# 3        Eric Williams     4296000
# 4        Adam Morrison     3616680
# 5         Jeff McInnis     3600000
# 6       Raymond Felton     3060840
# 7        Primoz Brezec     2750000
# 8   Othella Harrington     2200000
# 9         Jake Voskuhl     2000000
# 10     Walter Herrmann     1800000
# 11            Sean May     1740720
# 12        Matt Carroll     1188000
# 13      Derek Anderson      901397
# 14        Ryan Hollins      412718
# 15       Alan Anderson      102131
# 16      Kevin Burleson       70000
# 17              Totals    41964046
#         player_names  salary ($)
# 0     Gerald Wallace     5000000
# 1      Brevin Knight     4600000
# 2       Emeka Okafor     4020120
# 3        Kareem Rush     3000000
# 4     Raymond Felton     2847360
# 5      Primoz Brezec     2750000
# 6         Melvin Ely     2401027
# 7       Jake Voskuhl     1937500
# 8      Jumaine Jones     1875000
# 9           Sean May     1619280
# 10      Matt Carroll     1100000
# 11      Keith Bogans      869373
# 12  Bernard Robinson      641748
# 13     Alan Anderson      398762
# 14    Kevin Burleson      398762
# 15            Totals    33458932
#         player_names  salary ($)
# 0       Jahidi White     6166466
# 1       Emeka Okafor     3739680
# 2         Melvin Ely     1742400
# 3     Gerald Wallace     1652453
# 4      Primoz Brezec     1554326
# 5         Jason Hart     1400000
# 6        Kareem Rush     1174200
# 7        Steve Smith     1100000
# 8      Brevin Knight      932546
# 9        Eddie House      825000
# 10     Jamal Sampson      695046
# 11        Tamar Slay      695046
# 12      Jason Kapono      620046
# 13      Keith Bogans      620046
# 14      Theron Smith      620046
# 15  Bernard Robinson      385277
# 16            Totals    23922578
# Empty DataFrame
# Columns: [player_names, salary ($)]
# Index: []
# Empty DataFrame
# Columns: [player_names, salary ($)]
# Index: []
#          player_names  salary ($)
# 0      Elden Campbell     7975000
# 1      Jamal Mashburn     6975000
# 2            PJ Brown     6404800
# 3        Bobby Phills     5220000
# 4        David Wesley     3240000
# 5         Baron Davis     3119400
# 6      Robert Traylor     2793505
# 7        George Lynch     2400000
# 8       Stacey Augmon     2400000
# 9        Jerome Moiso     1571640
# 10         Bryce Drew     1300000
# 11       Matt Bullard     1300000
# 12  Eldridge Recasner     1300000
# 13        Kirk Haston     1182600
# 14    Jamaal Magloire     1048080
# 15          Tim James      837720
# 16         Lee Nailon      465850
# 17       Chris Porter      465850
# 18             Totals    49999445
# 600
# 600 600

# %% [markdown]
# ### Know we are going to do the same but WITH the implementation of another column that will contain the position each player plays in

# %% [markdown]
# #### While running our program the first time it has been noticed that some data were problematic. It has been decided to drop those problematic data by throwing exceptions and keep track of the data we are not importing

# %%
payrolls=dict()
kickout=[]
dropped=[]
counter=0
for i in range(0,len(team_names)):
    for j in range(0,len(years)):
            
        counter=counter+1    
        problematic=False    
        url = f"https://hoopshype.com/salaries/{team_names[i]}/{years[j]}/"
        salary_table = []
        try:
            r = requests.get(url,timeout=6)
            r_html = r.text
            soup = BeautifulSoup(r_html, 'html.parser')
            salary_table = soup.find('table')
        except:
            print("Something wrong")
        length=len(salary_table.find_all("td"))
        player_names=[salary_table.find_all("td")[i].text.strip() for i in range(3,length,3)]
        column1=[salary_table.find_all("td")[i].text.strip() for i in range(4,length,3)]
        
        #Creating the new column for players position via entering each players personal URL in hoopshype
        column2 = []
        for k in range(0,len(player_names)):
            if k == len(player_names)-1:
                column2.append("NaN")
                break
            player_name_trans = player_names[k].replace(' ','-')
            url_player = f"https://hoopshype.com/player/{player_name_trans}/salary/"
            r = requests.get(url_player,timeout=5)
            r_html = r.text
            try:
                soup = BeautifulSoup(r_html, 'html.parser')
                htmlText = soup.find_all("span", class_="player-bio-text-line-value")
                positionString = str(htmlText[0])
                position = positionString.find(">")
                column2.append(positionString[position+1])
            except IndexError as e:
                    kickout.append(f"{team_names[i]}{years[j]}")
                    dropped.append(f"({i},{j})")
                    print(i,j)
                    problematic= True
                    break
            except AttributeError as e1:
                    kickout.append(f"{team_names[i]}{years[j]}")
                    dropped.append(f"({i},{j})")
                    print(i,j)
                    problematic= True
                    break
        if problematic==False:
            salary_table = []
            try:
                r = requests.get(url,timeout=6)
                r_html = r.text
                soup = BeautifulSoup(r_html, 'html.parser')
                salary_table = soup.find('table')
            except:
                print("Something wrong")

            df_dict={'player_names':player_names,
                    'salary ($)':column1,
                        'position':column2}



            tempDataFrame=pd.DataFrame(df_dict)

            tempDataFrame.replace({'\$':''}, regex = True,inplace=True)
            tempDataFrame.replace(',','', regex=True, inplace=True)
            for item in tempDataFrame.columns[1:2]:
                tempDataFrame[item]=pd.to_numeric(tempDataFrame[item])
            if counter%25==0:
                print(counter)
                print(tempDataFrame)
            payrolls[f"{team_names[i]}{years[j]}"] = tempDataFrame
            
            
len(payrolls)
len(kickout,dropped)
print(kickout)
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     452             try:
# --> 453                 cnx.do_handshake()
#     454             except OpenSSL.SSL.WantReadError:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1906         result = _lib.SSL_do_handshake(self._ssl)
# -> 1907         self._raise_ssl_error(self._ssl, result)
#    1908
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     343         if HAS_SNI and server_hostname is not None:
# --> 344             return context.wrap_socket(sock, server_hostname=server_hostname)
#     345
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455                 if not util.wait_for_read(sock, sock.gettimeout()):
# --> 456                     raise timeout('select timed out')
#     457                 continue
#
# timeout: select timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     366             if read is False or not self._is_method_retryable(method):
# --> 367                 raise six.reraise(type(error), error, _stacktrace)
#     368             elif read is not None:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     685             raise value.with_traceback(tb)
# --> 686         raise value
#     687
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
# --> 346             self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#     347             raise
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     305         if isinstance(err, SocketTimeout):
# --> 306             raise ReadTimeoutError(self, url, "Read timed out. (read timeout=%s)" % timeout_value)
#     307
#
# ReadTimeoutError: HTTPSConnectionPool(host='hoopshype.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-12-bab2a846b88f> in <module>
#      29             player_name_trans = player_names[k].replace(' ','-')
#      30             url_player = f"https://hoopshype.com/player/{player_name_trans}/salary/"
# ---> 31             r = requests.get(url_player,timeout=5)
#      32             r_html = r.text
#      33             try:
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     527                 raise SSLError(e, request=request)
#     528             elif isinstance(e, ReadTimeoutError):
# --> 529                 raise ReadTimeout(e, request=request)
#     530             else:
#     531                 raise
#
# ReadTimeout: HTTPSConnectionPool(host='hoopshype.com', port=443): Read timed out. (read timeout=5)

# %% [markdown]
# ### Below we will print the same instance with and without the players position column by calling it in different payroll dictionary
